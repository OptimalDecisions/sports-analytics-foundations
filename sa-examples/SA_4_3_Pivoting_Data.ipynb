# %% [markdown]
# <a href="https://colab.research.google.com/github/OptimalDecisions/sports-analytics-foundations/blob/main/getting-started/SA_4_3_Pivoting_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   ## Pandas Full Example of Data Preparation

# %% [markdown]
#   # Pivoting Data into A Different Format
#
#   <img src = "../img/sa_logo.png" width="100" align="left">
#
#   Ram Narasimhan
#
#   <br><br><br>
#
#   << [3.0 Visualization Overview](Data_Visualization_3_0_Overview.ipynb) | [3.1 Visualization Using Pandas](Pandas_Intermediate_2_10_GroupBy.ipynb)  |
#   [3.2 Matplotlib Basics](Data_Visualization_3_2_Matplotlib_Basics.ipynb) >>

# %% [markdown]
# Concepts covered in this notebook.
#
# 1. Heatmaps
# 2. Pairplots
# 3. Color Palettes in Seabor

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## NFL 2022 Season Data

# %%
url = 'https://raw.githubusercontent.com/OptimalDecisions/sports-analytics-foundations/main/data/nfl_2022_games.csv'
nfl = pd.read_csv(url)

# %%
nfl.sample(10)
# Out:
#           Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 159         11  Sun  2022-11-20  4:05PM    Las Vegas Raiders          @
# 179         12  Mon  2022-11-28  8:15PM  Pittsburgh Steelers          @
# 146         10  Sun  2022-11-13  4:25PM    Green Bay Packers        NaN
# 25           2  Sun  2022-09-18  4:05PM  San Francisco 49ers        NaN
# 283  ConfChamp  Sun  2023-01-29  6:30PM   Kansas City Chiefs        NaN
# 129          9  Sun  2022-11-06  1:00PM       Miami Dolphins          @
# 63           4  Mon  2022-10-03  8:15PM  San Francisco 49ers        NaN
# 6            1  Sun  2022-09-11  1:00PM  Philadelphia Eagles          @
# 277   WildCard  Mon  2023-01-16  8:15PM       Dallas Cowboys          @
# 82           6  Sun  2022-10-16  1:00PM   Cincinnati Bengals          @
#
#                 Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL
# 159        Denver Broncos   boxscore  22.0  16.0  407.0  0.0  320.0  0.0
# 179    Indianapolis Colts   boxscore  24.0  17.0  323.0  0.0  290.0  2.0
# 146        Dallas Cowboys   boxscore  31.0  28.0  415.0  2.0  421.0  2.0
# 25       Seattle Seahawks   boxscore  27.0   7.0  373.0  0.0  216.0  3.0
# 283    Cincinnati Bengals   boxscore  23.0  20.0  357.0  1.0  309.0  2.0
# 129         Chicago Bears   boxscore  35.0  32.0  379.0  0.0  368.0  0.0
# 63       Los Angeles Rams   boxscore  24.0   9.0  327.0  0.0  257.0  2.0
# 6           Detroit Lions   boxscore  38.0  35.0  455.0  0.0  386.0  1.0
# 277  Tampa Bay Buccaneers   boxscore  31.0  14.0  425.0  0.0  386.0  1.0
# 82     New Orleans Saints   boxscore  30.0  26.0  348.0  1.0  399.0  0.0

# %% [markdown]
# Validation check: If there are any "bad" rows, we need to get rid of those.

# %%
nfl[nfl['Week'].isnull()]
# Out:
#     Week  Day      Date Time Winner/tie Unnamed: 5 Loser/tie Unnamed: 7  PtsW  \
# 271  NaN  NaN  Playoffs  NaN        NaN        NaN       NaN        NaN   NaN
#
#      PtsL  YdsW  TOW  YdsL  TOL
# 271   NaN   NaN  NaN   NaN  NaN

# %% [markdown]
# There is one row in this dataset, that is non-standard. Let's find that row and get rid of it!

# %%
nfl.isnull().sum()
# Out:
# Week            1
# Day             1
# Date            0
# Time            1
# Winner/tie      1
# Unnamed: 5    162
# Loser/tie       1
# Unnamed: 7      1
# PtsW            1
# PtsL            1
# YdsW            1
# TOW             1
# YdsL            1
# TOL             1
# dtype: int64

# %% [markdown]
# Since we cannot have "Week" or "Winner/tie" etc be Null, let's see which one it is.

# %%
nfl.dropna(subset=['Week'], inplace=True)

# %%
columns_to_keep = ['Week', 'Winner/tie', 'PtsW', "YdsW", 'Loser/tie', "PtsL", 'YdsL']
nfl = nfl[columns_to_keep]
nfl.rename(columns = {'Winner/tie': "Winner", "Loser/tie":'Loser'},inplace=True)
# Out:
# <ipython-input-7-e3b1fde75186>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nfl.rename(columns = {'Winner/tie': "Winner", "Loser/tie":'Loser'},inplace=True)

# %%
nfl
# Out:
#           Week               Winner  PtsW   YdsW                Loser  PtsL  \
# 0            1        Buffalo Bills  31.0  413.0     Los Angeles Rams  10.0
# 1            1   New Orleans Saints  27.0  385.0      Atlanta Falcons  26.0
# 2            1     Cleveland Browns  26.0  355.0    Carolina Panthers  24.0
# 3            1        Chicago Bears  19.0  204.0  San Francisco 49ers  10.0
# 4            1  Pittsburgh Steelers  23.0  267.0   Cincinnati Bengals  20.0
# ..         ...                  ...   ...    ...                  ...   ...
# 280   Division   Cincinnati Bengals  27.0  412.0        Buffalo Bills  10.0
# 281   Division  San Francisco 49ers  19.0  312.0       Dallas Cowboys  12.0
# 282  ConfChamp  Philadelphia Eagles  31.0  269.0  San Francisco 49ers   7.0
# 283  ConfChamp   Kansas City Chiefs  23.0  357.0   Cincinnati Bengals  20.0
# 284  SuperBowl   Kansas City Chiefs  38.0  340.0  Philadelphia Eagles  35.0
#
#       YdsL
# 0    243.0
# 1    416.0
# 2    261.0
# 3    331.0
# 4    432.0
# ..     ...
# 280  325.0
# 281  282.0
# 282  164.0
# 283  309.0
# 284  417.0
#
# [284 rows x 7 columns]

# %%
tidy_df = pd.melt(nfl, id_vars=['Week', 'Winner', 'Loser'],
                  value_vars=['YdsW', 'YdsL', 'PtsW', 'PtsL'],
                  var_name='Metric', value_name='Value')

tidy_df
# Out:
#            Week               Winner                Loser Metric  Value
# 0             1        Buffalo Bills     Los Angeles Rams   YdsW  413.0
# 1             1   New Orleans Saints      Atlanta Falcons   YdsW  385.0
# 2             1     Cleveland Browns    Carolina Panthers   YdsW  355.0
# 3             1        Chicago Bears  San Francisco 49ers   YdsW  204.0
# 4             1  Pittsburgh Steelers   Cincinnati Bengals   YdsW  267.0
# ...         ...                  ...                  ...    ...    ...
# 1131   Division   Cincinnati Bengals        Buffalo Bills   PtsL   10.0
# 1132   Division  San Francisco 49ers       Dallas Cowboys   PtsL   12.0
# 1133  ConfChamp  Philadelphia Eagles  San Francisco 49ers   PtsL    7.0
# 1134  ConfChamp   Kansas City Chiefs   Cincinnati Bengals   PtsL   20.0
# 1135  SuperBowl   Kansas City Chiefs  Philadelphia Eagles   PtsL   35.0
#
# [1136 rows x 5 columns]

# %%
# If the Metric is YdsW or PtsW, then we label is a winner_row
tidy_df['winner_row'] = tidy_df['Metric'].str.endswith('W')

# %%
# We only want to store one Team per row
#If it is a winner's metric, we will store the winning team.
# if the metric refers to teh losing team, we will store the losing team
# We go row by row and check the Metric and choose the correct team...

tidy_df['Team'] = tidy_df.apply(lambda row:
                                row['Winner'] if row['winner_row'] \
                                else row['Loser'],
                                axis=1)

# %%
tidy_df
# Out:
#            Week               Winner                Loser Metric  Value  \
# 0             1        Buffalo Bills     Los Angeles Rams   YdsW  413.0
# 1             1   New Orleans Saints      Atlanta Falcons   YdsW  385.0
# 2             1     Cleveland Browns    Carolina Panthers   YdsW  355.0
# 3             1        Chicago Bears  San Francisco 49ers   YdsW  204.0
# 4             1  Pittsburgh Steelers   Cincinnati Bengals   YdsW  267.0
# ...         ...                  ...                  ...    ...    ...
# 1131   Division   Cincinnati Bengals        Buffalo Bills   PtsL   10.0
# 1132   Division  San Francisco 49ers       Dallas Cowboys   PtsL   12.0
# 1133  ConfChamp  Philadelphia Eagles  San Francisco 49ers   PtsL    7.0
# 1134  ConfChamp   Kansas City Chiefs   Cincinnati Bengals   PtsL   20.0
# 1135  SuperBowl   Kansas City Chiefs  Philadelphia Eagles   PtsL   35.0
#
#       winner_row                 Team
# 0           True        Buffalo Bills
# 1           True   New Orleans Saints
# 2           True     Cleveland Browns
# 3           True        Chicago Bears
# 4           True  Pittsburgh Steelers
# ...          ...                  ...
# 1131       False        Buffalo Bills
# 1132       False       Dallas Cowboys
# 1133       False  San Francisco 49ers
# 1134       False   Cincinnati Bengals
# 1135       False  Philadelphia Eagles
#
# [1136 rows x 7 columns]

# %%
# Drop unnecessary columns
tidy_df = tidy_df[['Week', 'Team', 'Metric', 'Value']].copy()
#tidy_df['Result'] = tidy_df['Result'].str.replace('Yds', "")
tidy_df
# Out:
#            Week                 Team Metric  Value
# 0             1        Buffalo Bills   YdsW  413.0
# 1             1   New Orleans Saints   YdsW  385.0
# 2             1     Cleveland Browns   YdsW  355.0
# 3             1        Chicago Bears   YdsW  204.0
# 4             1  Pittsburgh Steelers   YdsW  267.0
# ...         ...                  ...    ...    ...
# 1131   Division        Buffalo Bills   PtsL   10.0
# 1132   Division       Dallas Cowboys   PtsL   12.0
# 1133  ConfChamp  San Francisco 49ers   PtsL    7.0
# 1134  ConfChamp   Cincinnati Bengals   PtsL   20.0
# 1135  SuperBowl  Philadelphia Eagles   PtsL   35.0
#
# [1136 rows x 4 columns]

# %%
# prompt: how to check if the string "1wild" is in any of the tidy_df['week']'s rows

# %%
# Out:
# True

# %%
# Add a "0" to values from "1" through "9"
tidy_df['Week'] = tidy_df['Week'].apply(
    lambda x: x.zfill(2) if x.isdigit() and 1 <= int(x) <= 9 else x)

#the following condition makes sure that we don't rename twice
if not(any(tidy_df['Week'].str.contains('1wild'))):
  tidy_df['Week'] = tidy_df['Week'].str.replace("Wild", "1Wild")
  tidy_df['Week'] = tidy_df['Week'].str.replace("Div", "2Div")

# %%
# Keep only one metric - YdsW
moi = 'Yds'
mini = tidy_df[tidy_df['Metric'].str.contains(moi)].copy()

# %%
mini
# Out:
#           Week                 Team Metric  Value
# 0           01        Buffalo Bills   YdsW  413.0
# 1           01   New Orleans Saints   YdsW  385.0
# 2           01     Cleveland Browns   YdsW  355.0
# 3           01        Chicago Bears   YdsW  204.0
# 4           01  Pittsburgh Steelers   YdsW  267.0
# ..         ...                  ...    ...    ...
# Chicago Bears          259.0        NaN        NaN        NaN        NaN
# Cincinnati Bengals     257.0      234.0      412.0      309.0        NaN
# Cleveland Browns       307.0        NaN        NaN        NaN        NaN
# Dallas Cowboys         182.0      425.0      282.0        NaN        NaN
# Denver Broncos         471.0        NaN        NaN        NaN        NaN
# Detroit Lions          323.0        NaN        NaN        NaN        NaN
# Green Bay Packers      291.0        NaN        NaN        NaN        NaN
# Houston Texans         360.0        NaN        NaN        NaN        NaN
# Indianapolis Colts     398.0        NaN        NaN        NaN        NaN
# Jacksonville Jaguars   222.0      390.0      349.0        NaN        NaN
# Kansas City Chiefs     349.0        NaN      362.0      357.0      340.0
# Las Vegas Raiders      279.0        NaN        NaN        NaN        NaN
# Los Angeles Chargers   352.0      320.0        NaN        NaN        NaN
# Los Angeles Rams       269.0        NaN        NaN        NaN        NaN
# Miami Dolphins         302.0      231.0        NaN        NaN        NaN
# Minnesota Vikings      482.0      332.0        NaN        NaN        NaN
# New England Patriots   341.0        NaN        NaN        NaN        NaN
# New Orleans Saints     304.0        NaN        NaN        NaN        NaN
# New York Giants        284.0      431.0      227.0        NaN        NaN
# New York Jets          187.0        NaN        NaN        NaN        NaN
# Philadelphia Eagles    342.0        NaN      416.0      269.0      417.0
# Pittsburgh Steelers    333.0        NaN        NaN        NaN        NaN
# San Francisco 49ers    311.0      505.0      312.0      164.0        NaN
# Seattle Seahawks       402.0      332.0        NaN        NaN        NaN
# Tampa Bay Buccaneers   222.0      386.0        NaN        NaN        NaN
# Tennessee Titans       312.0        NaN        NaN        NaN        NaN
# Washington Commanders  309.0        NaN        NaN        NaN        NaN
#
# [32 rows x 22 columns]

# %%
heat_pts
# Out:
# Week                     01    02    03    04    05    06    07    08    09  \
# Team
# Arizona Cardinals      21.0  29.0  12.0  26.0  17.0   9.0  42.0  26.0  21.0
# Atlanta Falcons        26.0  27.0  27.0  23.0  15.0  28.0  17.0  37.0  17.0
# Baltimore Ravens       24.0  38.0  37.0  20.0  19.0  20.0  23.0  27.0  27.0
# Buffalo Bills          31.0  41.0  19.0  23.0  38.0  24.0   NaN  27.0  17.0
# Carolina Panthers      24.0  16.0  22.0  16.0  15.0  10.0  21.0  34.0  21.0
# Chicago Bears          19.0  10.0  23.0  12.0  22.0   7.0  33.0  29.0  32.0
# Cincinnati Bengals     20.0  17.0  27.0  27.0  17.0  30.0  35.0  13.0  42.0
# Cleveland Browns       26.0  30.0  29.0  20.0  28.0  15.0  20.0  32.0   NaN
# Dallas Cowboys          3.0  20.0  23.0  25.0  22.0  17.0  24.0  49.0   NaN
# Denver Broncos         16.0  16.0  11.0  23.0   9.0  16.0   9.0  21.0   NaN
# Detroit Lions          35.0  36.0  24.0  45.0   0.0   NaN   6.0  27.0  15.0
# Green Bay Packers       7.0  27.0  14.0  27.0  22.0  10.0  21.0  17.0   9.0
# Houston Texans         20.0   9.0  20.0  24.0  13.0   NaN  20.0  10.0  17.0
# Indianapolis Colts     20.0   0.0  20.0  17.0  12.0  34.0  10.0  16.0   3.0
# Jacksonville Jaguars   22.0  24.0  38.0  21.0   6.0  27.0  17.0  17.0  27.0
# Kansas City Chiefs     44.0  27.0  17.0  41.0  30.0  20.0  44.0   NaN  20.0
# New England Patriots    NaN  ...  10.0  27.0  24.0  18.0  23.0  23.0
# New Orleans Saints     10.0  ...  16.0   NaN  21.0  17.0  20.0   7.0
# New York Giants        24.0  ...  20.0  22.0  20.0  24.0  38.0  16.0
# New York Jets           NaN  ...  22.0  12.0  17.0   3.0   6.0   6.0
# Philadelphia Eagles    21.0  ...  35.0  48.0  25.0  34.0  10.0  22.0
# Pittsburgh Steelers    20.0  ...  19.0  14.0  24.0  13.0  16.0  28.0
# San Francisco 49ers    22.0  ...  33.0  35.0  21.0  37.0  37.0  38.0
# Seattle Seahawks       16.0  ...  27.0  24.0  13.0  10.0  23.0  19.0
# Tampa Bay Buccaneers   21.0  ...  17.0   7.0  23.0  19.0  30.0  17.0
# Tennessee Titans       17.0  ...  10.0  22.0  14.0  14.0  13.0  16.0
# Washington Commanders  32.0  ...  20.0   NaN  12.0  20.0  10.0  26.0
#
# Week                   1WildCard  2Division  ConfChamp  SuperBowl
# Team
# Arizona Cardinals            NaN        NaN        NaN        NaN
# Atlanta Falcons              NaN        NaN        NaN        NaN
# Baltimore Ravens            17.0        NaN        NaN        NaN
# Buffalo Bills               34.0       10.0        NaN        NaN
# Carolina Panthers            NaN        NaN        NaN        NaN
# Chicago Bears                NaN        NaN        NaN        NaN
# Cincinnati Bengals          24.0       27.0       20.0        NaN
# Cleveland Browns             NaN        NaN        NaN        NaN
# Dallas Cowboys              31.0       12.0        NaN        NaN
# Denver Broncos               NaN        NaN        NaN        NaN
# Detroit Lions                NaN        NaN        NaN        NaN
# Green Bay Packers            NaN        NaN        NaN        NaN
# Houston Texans               NaN        NaN        NaN        NaN
# Indianapolis Colts           NaN        NaN        NaN        NaN
# Jacksonville Jaguars        31.0       20.0        NaN        NaN
# Kansas City Chiefs           NaN       27.0       23.0       38.0
# Las Vegas Raiders            NaN        NaN        NaN        NaN
# Los Angeles Chargers        30.0        NaN        NaN        NaN
# Los Angeles Rams             NaN        NaN        NaN        NaN
# Miami Dolphins              31.0        NaN        NaN        NaN
# Minnesota Vikings           24.0        NaN        NaN        NaN
# New England Patriots         NaN        NaN        NaN        NaN
# New Orleans Saints           NaN        NaN        NaN        NaN
# New York Giants             31.0        7.0        NaN        NaN
# New York Jets                NaN        NaN        NaN        NaN
# Philadelphia Eagles          NaN       38.0       31.0       35.0
# Pittsburgh Steelers          NaN        NaN        NaN        NaN
# San Francisco 49ers         41.0       19.0        7.0        NaN
# Seattle Seahawks            23.0        NaN        NaN        NaN
# Tampa Bay Buccaneers        14.0        NaN        NaN        NaN
# Tennessee Titans             NaN        NaN        NaN        NaN
# Washington Commanders        NaN        NaN        NaN        NaN
#
# [32 rows x 22 columns]

# %%
# Create a customized heatmap
plt.figure(figsize=(12,10))
sns.heatmap(heat_yds, cmap="YlGnBu", linewidths=.5)

# Add title and labels
plt.title("Yards Gained by Team by Week")
plt.xlabel("Week")
plt.ylabel("Team")

# Show the plot
plt.show()

# %%
# Create a customized heatmap
plt.figure(figsize=(12,10))
sns.heatmap(heat_pts,  cmap="RdYlGn", linewidths=.5)

# Add title and labels
plt.title("Yards Gained by Team by Week")
plt.xlabel("Week")
plt.ylabel("Team")

# Show the plot
plt.show()
