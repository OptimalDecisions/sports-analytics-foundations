# %% [markdown]
# <a href="https://colab.research.google.com/github/OptimalDecisions/sports-analytics-foundations/blob/main/pandas-bascs/Pandas_Exercise_2_9_Exer_Merging_Dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas Exercises 2.9

# %% [markdown]
# # Merging Dataframes
#
# <img src = "../img/sa_logo.png" width="100" align="left">
#
# Ram Narasimhan
#
#   <br><br><br>
#
# This notebook contains exercises based on the topics covered in [notebook 2.9](https://github.com/OptimalDecisions/sports-analytics-foundations/blob/main/pandas-basics/Pandas_Basics_2_9_Merging_Dataframes.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Exercise 1: Merging Real Team and Player Data
#
# We have two dataframes, one containing information about players and another about football teams.
#
# But we want to work with one combined dataframe.

# %%
player_data = {'PlayerID': [1, 2, 3],
               'Name': ['Messi', 'Ronaldo', 'Neymar'],
               'TeamID': [101, 102, 101]}

players = pd.DataFrame(player_data)

# Sample Team Data with Real Team Names
team_data = {'TeamID': [101, 102, 103],
             'TeamName': ['FC Barcelona', 'Real Madrid', 'Paris Saint-Germain']}

teams = pd.DataFrame(team_data)

players
# Out:
#    PlayerID     Name  TeamID
# 0         1    Messi     101
# 1         2  Ronaldo     102
# 2         3   Neymar     101

# %%
teams
# Out:
#    TeamID             TeamName
# 0     101         FC Barcelona
# 1     102          Real Madrid
# 2     103  Paris Saint-Germain

# %% [markdown]
# Tasks for Exercise 1
#
# - Use pd.merge() to combine the 'players' and 'teams' dataframes based on the 'TeamID' column.
# - Display the merged dataframe showing player names, player IDs, team IDs, and real team names.

# %% [markdown]
# ## Exercise 2: Merging Real Match and Venue Data
#
# We have two dataframes, one containing information about football matches and another about stadiums.

# %%
# Sample Match Data
match_data = {'MatchID': [1, 2, 3],
              'TeamA': ['FC Barcelona', 'Real Madrid', 'Paris Saint-Germain'],
              'TeamB': ['Real Madrid', 'Paris Saint-Germain', 'FC Barcelona'],
              'VenueID': [101, 102, 101]}

matches = pd.DataFrame(match_data)

# Sample Venue Data with Real Stadium Names
venue_data = {'VenueID': [101, 102, 103],
              'VenueName': ['Camp Nou', 'Santiago Bernabeu', 'Parc des Princes']}

venues = pd.DataFrame(venue_data)

# %% [markdown]
# ### Tasks for Exercise 2
#
# - Use `pd.merge()` to combine the `matches` and `venues` dataframes based on the 'VenueID' column.
# - Display the merged dataframe showing match IDs, team A names, team B names, venue IDs, and real venue names.
