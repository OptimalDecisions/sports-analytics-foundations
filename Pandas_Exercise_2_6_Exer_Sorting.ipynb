# %% [markdown]
# <a href="https://colab.research.google.com/github/OptimalDecisions/sports-analytics-foundations/blob/main/Pandas_Exercise_2_6_Exer_Sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas Exercises 2.6

# %% [markdown]
# # Sorting
#
# <img src = "../img/sa_logo.png" width="100" align="left">
#
#   Ram Narasimhan
#
#   <br><br><br>
#
#
# This notebook contains exercises based on the sort topics covered in [notebook 2.6](https://github.com/OptimalDecisions/sports-analytics-foundations/blob/main/pandas-basics/Pandas_Basics_2_6_Sorting.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Exercise 1: Using sort_values() Method
#
# Ascending Order (NBA Points):

# %%
nba_players = pd.DataFrame({
    'Player': ['LeBron James', 'Stephen Curry', 'Kevin Durant', 'Giannis Antetokounmpo', 'Luka Dončić'],
    'Points_Per_Game': [25.0, 28.2, 27.3, 29.5, 26.9],
})

nba_players
# Out:
#                   Player  Points_Per_Game
# 0           LeBron James             25.0
# 1          Stephen Curry             28.2
# 2           Kevin Durant             27.3
# 3  Giannis Antetokounmpo             29.5
# 4            Luka Dončić             26.9

# %% [markdown]
# - Sort the DataFrame by 'Points_Per_Game' in ascending order. Print the resulting DataFrame.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Sort by Team Name (NFL):
#
# Consider the NFL team DataFrame nfl_teams with columns 'Team_Name' and 'Superbowl_Wins'.

# %%
nfl_teams = pd.DataFrame({
    'Team_Name': ['Patriots', 'Cowboys', 'Packers', 'Steelers', '49ers'],
    'Superbowl_Wins': [6, 5, 4, 6, 5],
})

nfl_teams
# Out:
#   Team_Name  Superbowl_Wins
# 0  Patriots               6
# 1   Cowboys               5
# 2   Packers               4
# 3  Steelers               6
# 4     49ers               5

# %% [markdown]
# - Sort the DataFrame by `Team_Name` in ascending order. Print the resulting DataFrame.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Ascending and Descending Order
#
# - Descending Order by NFL Team Wins:

# %%
nfl_teams = pd.DataFrame({
    'Team_Name': ['Patriots', 'Cowboys', 'Packers', 'Steelers', '49ers'],
    'Wins_Last_Season': [10, 8, 11, 9, 12],
})

nfl_teams
# Out:
#   Team_Name  Wins_Last_Season
# 0  Patriots                10
# 1   Cowboys                 8
# 2   Packers                11
# 3  Steelers                 9
# 4     49ers                12

# %% [markdown]
# Sort the DataFrame by `Wins_Last_Season` in descending order. Print the resulting DataFrame.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4: Descending Order by NBA Player Efficiency
#
# Consider the NBA player statistics DataFrame nba_players with columns 'Player' and 'Player_Efficiency_Rating'.

# %%
nba_players = pd.DataFrame({
    'Player': ['LeBron James', 'Stephen Curry', 'Kevin Durant', 'Giannis Antetokounmpo', 'Luka Dončić'],
    'Player_Efficiency_Rating': [25.3, 30.4, 28.7, 32.1, 28.9],
})

nba_players
# Out:
#                   Player  Player_Efficiency_Rating
# 0           LeBron James                      25.3
# 1          Stephen Curry                      30.4
# 2           Kevin Durant                      28.7
# 3  Giannis Antetokounmpo                      32.1
# 4            Luka Dončić                      28.9

# %% [markdown]
# Use the `sort_values()` method to sort the DataFrame by `Player_Efficiency_Rating` in descending order. Print the resulting DataFrame.

# %%
# Your code to sort here

# %% [markdown]
# ## Exercise 5: Sort by Multiple Columns
#
# Given the NBA player statistics DataFrame nba_players with columns `Points_Per_Game`, `Assists_Per_Game`, and `Player`.

# %%
nba_players = pd.DataFrame({
    'Player': ['LeBron James', 'Stephen Curry', 'Kevin Durant', 'Giannis Antetokounmpo', 'Luka Dončić'],
    'Points_Per_Game': [25.0, 28.2, 27.3, 29.5, 26.9],
    'Assists_Per_Game': [8.1, 6.2, 5.5, 6.4, 8.6],
})

nba_players
# Out:
#                   Player  Points_Per_Game  Assists_Per_Game
# 0           LeBron James             25.0               8.1
# 1          Stephen Curry             28.2               6.2
# 2           Kevin Durant             27.3               5.5
# 3  Giannis Antetokounmpo             29.5               6.4
# 4            Luka Dončić             26.9               8.6

# %% [markdown]
# Exercise: Sort the DataFrame first by `Points_Per_Game` in descending order and then by `Assists_Per_Game` in ascending order. Print the resulting DataFrame.

# %%
#your code to sort here

# %% [markdown]
# ## Exercise 6: Sort by Player Position (Soccer):
#
# Consider the soccer player DataFrame soccer_players with columns `Player_Name`, `Position`, and `Goals_Scored`.

# %%
soccer_players = pd.DataFrame({
    'Player_Name': ['Messi', 'Ronaldo', 'Neymar', 'Mbappe', 'Haaland'],
    'Position': ['Forward', 'Forward', 'Forward', 'Forward', 'Forward'],
    'Goals_Scored': [30, 28, 18, 20, 25],
})

soccer_players
# Out:
#   Player_Name Position  Goals_Scored
# 0       Messi  Forward            30
# 1     Ronaldo  Forward            28
# 2      Neymar  Forward            18
# 3      Mbappe  Forward            20
# 4     Haaland  Forward            25

# %% [markdown]
# Sort the DataFrame by `Position` in ascending order and then by `Goals_Scored` in descending order. Print the resulting DataFrame.

# %%
#Your code to sort here
