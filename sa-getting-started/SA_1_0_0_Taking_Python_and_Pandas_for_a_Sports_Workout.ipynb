# %% [markdown]
# <a href="https://colab.research.google.com/github/OptimalDecisions/sports-analytics-foundations/blob/main/sa-getting-started/SA_1_0_0_Taking_Python_and_Pandas_for_a_Sports_Workout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: import pandas, matplotlib and make the plotting inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("/nfl_2022_games.csv")

# %%
df.sample(10)
# Out:
#     Week  Day        Date    Time            Winner/tie Unnamed: 5  \
# 65     5  Sun  2022-10-09  9:30AM       New York Giants          @
# 244   17  Sun  2023-01-01  1:00PM      Cleveland Browns          @
# 8      1  Sun  2022-09-11  1:00PM        Miami Dolphins        NaN
# 84     6  Sun  2022-10-16  1:00PM    Indianapolis Colts        NaN
# 166   12  Thu  2022-11-24  8:20PM     Minnesota Vikings        NaN
# 231   16  Sat  2022-12-24  1:00PM    Kansas City Chiefs        NaN
# 40     3  Sun  2022-09-25  1:00PM      Tennessee Titans        NaN
# 161   11  Sun  2022-11-20  4:25PM        Dallas Cowboys          @
# 175   12  Sun  2022-11-27  4:05PM  Los Angeles Chargers          @
# 162   11  Sun  2022-11-20  8:20PM    Kansas City Chiefs          @
#
#                  Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL
# 65       Green Bay Packers   boxscore  27.0  22.0  338.0  0.0  301.0  0.0
# 244  Washington Commanders   boxscore  24.0  10.0  301.0  0.0  260.0  3.0
# 8     New England Patriots   boxscore  20.0   7.0  307.0  0.0  271.0  3.0
# 84    Jacksonville Jaguars   boxscore  34.0  27.0  434.0  0.0  379.0  1.0
# 166   New England Patriots   boxscore  33.0  26.0  358.0  1.0  409.0  0.0
# 231       Seattle Seahawks   boxscore  24.0  10.0  297.0  0.0  333.0  1.0
# 40       Las Vegas Raiders   boxscore  24.0  22.0  361.0  1.0  396.0  1.0
# 161      Minnesota Vikings   boxscore  40.0   3.0  458.0  0.0  183.0  1.0
# 175      Arizona Cardinals   boxscore  25.0  24.0  311.0  0.0  366.0  2.0
# 162   Los Angeles Chargers   boxscore  30.0  27.0  485.0  1.0  365.0  2.0

# %%
df['Unnamed: 5'].unique()
# Out:
# array(['@', nan, 'N'], dtype=object)

# %%
df[df['Unnamed: 5'] == 'N']
# Out:
#           Week  Day        Date    Time          Winner/tie Unnamed: 5  \
# 284  SuperBowl  Sun  2023-02-12  6:30PM  Kansas City Chiefs          N
#
#                Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL
# 284  Philadelphia Eagles   boxscore  38.0  35.0  340.0  0.0  417.0  1.0

# %%
df['Margin'] = df['PtsW'] - df['PtsL']

# %%
df.sort_values(by = 'Margin', ascending=False)
# Out:
#     Week  Day        Date    Time             Winner/tie Unnamed: 5  \
# 161   11  Sun  2022-11-20  4:25PM         Dallas Cowboys          @
# 237   16  Sun  2022-12-25  4:30PM       Los Angeles Rams        NaN
# 67     5  Sun  2022-10-09  1:00PM          Buffalo Bills        NaN
# 193   13  Sun  2022-12-04  8:20PM         Dallas Cowboys        NaN
# 30     2  Mon  2022-09-19  7:15PM          Buffalo Bills        NaN
# ..   ...  ...         ...     ...                    ...        ...
# 119    8  Sun  2022-10-30  4:25PM  Washington Commanders          @
# 142   10  Sun  2022-11-13  1:00PM          Detroit Lions          @
# 185   13  Sun  2022-12-04  1:00PM  Washington Commanders          @
# 5      1  Sun  2022-09-11  1:00PM         Houston Texans        NaN
# 271  NaN  NaN    Playoffs     NaN                    NaN        NaN
#
#                Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 161    Minnesota Vikings   boxscore  40.0   3.0  458.0  0.0  183.0  1.0
# 237       Denver Broncos   boxscore  51.0  14.0  388.0  0.0  323.0  4.0
# 67   Pittsburgh Steelers   boxscore  38.0   3.0  552.0  2.0  364.0  2.0
# 193   Indianapolis Colts   boxscore  54.0  19.0  385.0  1.0  309.0  5.0
# 30      Tennessee Titans   boxscore  41.0   7.0  414.0  0.0  187.0  4.0
# ..                   ...        ...   ...   ...    ...  ...    ...  ...
# 119   Indianapolis Colts   boxscore  17.0  16.0  362.0  1.0  324.0  2.0
# 142        Chicago Bears   boxscore  31.0  30.0  323.0  0.0  408.0  1.0
# 185      New York Giants   boxscore  20.0  20.0  411.0  1.0  316.0  1.0
# 5     Indianapolis Colts   boxscore  20.0  20.0  299.0  1.0  517.0  2.0
# 271                  NaN        NaN   NaN   NaN    NaN  NaN    NaN  NaN
#
#      Margin
# 161    37.0
# 237    37.0
# 67     35.0
# 193    35.0
# 30     34.0
# ..      ...
# 119     1.0
# 142     1.0
# 185     0.0
# 5       0.0
# 271     NaN
#
# [285 rows x 15 columns]

# %%
# prompt: In this df, which row has the highest combined PtsW and PtsL?

df['Combined'] = df['PtsW'] + df['PtsL']
df.sort_values(by = 'Combined', ascending=False)
# Out:
#     Week  Day        Date    Time            Winner/tie Unnamed: 5  \
# 55     4  Sun  2022-10-02  1:00PM      Seattle Seahawks          @
# 21     2  Sun  2022-09-18  1:00PM        Miami Dolphins          @
# 113    8  Sun  2022-10-30  1:00PM        Dallas Cowboys        NaN
# 94     7  Thu  2022-10-20  8:15PM     Arizona Cardinals        NaN
# 209   15  Sat  2022-12-17  1:00PM     Minnesota Vikings        NaN
# ..   ...  ...         ...     ...                   ...        ...
# 210   15  Sat  2022-12-17  4:30PM      Cleveland Browns        NaN
# 156   11  Sun  2022-11-20  1:00PM      Baltimore Ravens        NaN
# 154   11  Sun  2022-11-20  1:00PM  New England Patriots        NaN
# 177   12  Sun  2022-11-27  4:25PM   San Francisco 49ers        NaN
# 271  NaN  NaN    Playoffs     NaN                   NaN        NaN
#
#               Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 55        Detroit Lions   boxscore  48.0  45.0  555.0  1.0  520.0  2.0
# 21     Baltimore Ravens   boxscore  42.0  38.0  547.0  2.0  473.0  0.0
# 113       Chicago Bears   boxscore  49.0  29.0  442.0  1.0  371.0  1.0
# 94   New Orleans Saints   boxscore  42.0  34.0  326.0  0.0  494.0  3.0
# 209  Indianapolis Colts   boxscore  39.0  36.0  518.0  3.0  341.0  1.0
# ..                  ...        ...   ...   ...    ...  ...    ...  ...
# 210    Baltimore Ravens   boxscore  13.0   3.0  283.0  0.0  324.0  2.0
# 156   Carolina Panthers   boxscore  13.0   3.0  308.0  1.0  205.0  3.0
# 154       New York Jets   boxscore  10.0   3.0  297.0  0.0  103.0  0.0
# 177  New Orleans Saints   boxscore  13.0   0.0  317.0  0.0  260.0  2.0
# 271                 NaN        NaN   NaN   NaN    NaN  NaN    NaN  NaN
#
#      Margin  Combined
# 55      3.0      93.0
# 21      4.0      80.0
# 113    20.0      78.0
# 94      8.0      76.0
# 209     3.0      75.0
# ..      ...       ...
# 210    10.0      16.0
# 156    10.0      16.0
# 154     7.0      13.0
# 177    13.0      13.0
# 271     NaN       NaN
#
# [285 rows x 16 columns]

# %%
# prompt: just show me the rows in which Pittshburgh Steelers are in the Winner/tie or Loser/tie column

cond = df['Winner/tie'].str.contains('Pittsburgh Steelers') | df['Loser/tie'].str.contains('Pittsburgh Steelers')
cond
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 280    False
# 281    False
# 282    False
# 283    False
# 284    False
# Length: 285, dtype: bool

# %%
pitt = df[cond].copy()

# %%
df.shape, pitt.shape
# Out:
# ((285, 16), (17, 16))
